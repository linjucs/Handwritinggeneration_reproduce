# %% [markdown]
# # Results

# %%
import sys
sys.path.insert(0, '..')
from utils import plot_stroke

# %% [markdown]
# This is what you should modify:

# %%
from models.task import generate_unconditionally, generate_conditionally, recognize_stroke

# %% [markdown]
# Please, don't modify anything below.
#
# ### Unconditional generation:

# %%
stroke = generate_unconditionally()
plot_stroke(stroke)

# %% [markdown]
# ### Conditional generation:

# %%
stroke = generate_conditionally(text='welcome to lyrebird')
plot_stroke(stroke)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-92f096dfc745> in <module>
# ----> 1 stroke = generate_conditionally(text='welcome to lyrebird')
#       2 plot_stroke(stroke)
#
# ~/Desktop/LAB_EXP/descript-research-test/models/task.py in generate_conditionally(text, random_seed)
#      46         model = ConditionalModel(use_cuda=use_cuda)
#      47
# ---> 48     model.load_state_dict(torch.load('../checkpoint/prediction_model'))
#      49     model.eval()
#      50     es = numpy.random.binomial(1, 0.8, 1)
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#     837         if len(error_msgs) > 0:
#     838             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# --> 839                                self.__class__.__name__, "\n\t".join(error_msgs)))
#     840         return _IncompatibleKeys(missing_keys, unexpected_keys)
#     841
#
# RuntimeError: Error(s) in loading state_dict for ConditionalModel:
# 	Missing key(s) in state_dict: "alpha.weight", "alpha.bias", "beta.weight", "beta.bias", "offset.weight", "offset.bias".
# 	size mismatch for lstm1.weight_ih: copying a param with shape torch.Size([1600, 3]) from checkpoint, the shape in current model is torch.Size([1600, 81]).
# 	size mismatch for lstm2.weight_ih: copying a param with shape torch.Size([1600, 403]) from checkpoint, the shape in current model is torch.Size([1600, 481]).
# 	size mismatch for lstm3.weight_ih: copying a param with shape torch.Size([1600, 403]) from checkpoint, the shape in current model is torch.Size([1600, 481]).

# %% [markdown]
# ### Handwriting recognition:

# %%
text = recognize_stroke(stroke)
print(text)
# Out:
# welcome to lyrebird
